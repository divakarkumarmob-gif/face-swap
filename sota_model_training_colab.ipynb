# %% [markdown]
# # 🚀 SOTA Face Swap AI - 1-Click Automated Model Training Suite
# ### Complete GPU Training Harness with ArcFace Identity Loss, SSIM Structural Loss, 512px Dataset Curation & ONNX/TensorRT Export.
#
# Follow these 3 simple steps to train your custom model on Google Colab's Free GPU:

# %% [markdown]
# ### Step 1: Check GPU Acceleration
# Make sure your Colab runtime is set to **GPU** (`Runtime` -> `Change runtime type` -> `T4 GPU`).

# %%
# !nvidia-smi

# %% [markdown]
# ### Step 2: Install Deep Learning & Vision Libraries

# %%
# !pip install -q onnx onnxruntime-gpu insightface opencv-python tqdm requests imageio imageio-ffmpeg

# %% [markdown]
# ### Step 3: Run 1-Click Automated Training & Export
# This script automatically:
# 1. Ingests & curates 512x512 high-res face training samples.
# 2. Extracts 512-D ArcFace identity embeddings & 3D head poses.
# 3. Trains the neural generator with Mixed Precision (AMP) & Multi-Objective Loss Suite.
# 4. Exports the final production model to `custom_sota_swapper_512.onnx`.

# %%
# Run training for 15 Epochs (You can change 15 to 30 or 50)
# !python backend/training/colab_training_runner.py 15
