# %% [markdown]
# # 🎭 Studio AI Face Swap (Photo & Video) - Kaggle GPU 1-Click Fast Runner
#
# Run the ultra-fast AI Face Swapping Studio with **Free 30 Hours/Week NVIDIA Tesla T4 GPU Acceleration**.
#
# > ⚙️ **MANDATORY KAGGLE SETTINGS (Right Sidebar -> Notebook Settings)**:
# > 1. **Accelerator**: Select `GPU T4 x 2` or `GPU P100`
# > 2. **Internet**: Toggle `Internet on` (Required for AI model download & Cloudflare link)

# %% [markdown]
# ### Step 1: Verify NVIDIA GPU & CUDA

# %%
# !nvidia-smi

# %% [markdown]
# ### Step 2: Install High-Speed GPU Dependencies & Clone Latest Code

# %%
import os
# 1. Clean workspace & clone latest high-speed code
# !rm -rf /kaggle/working/face-swap
# !git clone https://github.com/divakarkumarmob-gif/face-swap.git /kaggle/working/face-swap
# %cd /kaggle/working/face-swap

# 2. Remove any CPU-only ONNX runtime to prevent bottlenecks
# !pip uninstall -y onnxruntime

# 3. Install GPU-accelerated ONNX Runtime + Core dependencies
# !pip install -q onnxruntime-gpu --extra-index-url https://aiinfra.pkgs.visualstudio.com/PublicPackages/_packaging/onnxruntime-cuda-12/pypi/simple/
# !pip install -q -r requirements.txt

# 4. Verify GPU CUDA Execution Provider is Active
import onnxruntime
print('✅ Active ONNX Providers:', onnxruntime.get_available_providers())
if 'CUDAExecutionProvider' in onnxruntime.get_available_providers():
    print('🚀 SUCCESS: NVIDIA CUDA GPU IS ACTIVE & READY FOR FAST INFERENCE!')
else:
    print('⚠️ Notice: Running on CPU, check accelerator settings in sidebar.')

# %% [markdown]
# ### Step 3: Launch Face Swap Studio & Get Instant Live Link
# *(Click the generated `trycloudflare.com` URL below to open your studio)*

# %%
# %cd /kaggle/working/face-swap
# !python colab_launcher.py
