# %% [markdown]
# # 🎭 Studio AI Face Swap (Photo & Video) - Google Colab 1-Click Runner
#
# Run the high-fidelity AI Face Swapping Web Studio with **Free NVIDIA T4 GPU Acceleration** and generate an **instant 100% Free Public HTTPS URL**.
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/divakarkumarmob-gif/face-swap/blob/main/face_swap_colab.ipynb)

# %% [markdown]
# ### Step 1: Check GPU Acceleration
# *(Make sure `Runtime` > `Change runtime type` > `T4 GPU` is selected)*

# %%
# !nvidia-smi

# %% [markdown]
# ### Step 2: Clone/Update Repository & Install CUDA GPU Dependencies

# %%
import os
if not os.path.exists('/content/face-swap'):
    # %cd /content
    # !git clone https://github.com/divakarkumarmob-gif/face-swap.git
    # %cd /content/face-swap
else:
    # %cd /content/face-swap
    # !git pull origin main

# Install dependencies with GPU acceleration
# !pip install -r requirements.txt
# !pip install onnxruntime-gpu

# %% [markdown]
# ### Step 3: Launch Web Studio & Generate Instant Free Public Link
# *(Click the generated `trycloudflare.com` URL below to open your face swap studio from any device or mobile!)*

# %%
# %cd /content/face-swap
# !python colab_launcher.py
